# %% [markdown]
# # Document Cleanup

# %% [markdown]
# I propose seven binarization methods in the next script [binarization methods](binarization_methods.py)
#
# These are implemented in the scikit-image library
# - Otsu Global
# - Otsu Local
# - Adaptative_local
# - Niblack
# - Sauvola
#
# These was implement for the following papers
# - Su
#   - Robust document image binarization technique for degraded document images}
# - Relative Darknest Index
#   - Learning document image binarization from data

# %%
import cv2
import matplotlib.pyplot as plt
from binarization_methods import BinarizationMethod

# %% [markdown]
# ## Original images
# Reading a sample image from dataset

# %%
img_path = "noisy_data/2.png"
img = cv2.imread(img_path, 0)
plt.imshow(img, cmap='gray')
plt.show()
print("Image shape:", img.shape)
# Out:
# Image shape: (358, 640)

# %% [markdown]
# First I used the proposed binarization methods with sample image above.

# %% [markdown]
# ## Adaptive Thresholding

# %%
binary_method = BinarizationMethod(img_path)
print("Computing features ....")
# binary methods
binary_method.adaptative_local(); 
bin_otsu_g = binary_method.binary
plt.imshow(bin_otsu_g, cmap='gray')
# Out:
# Computing features ....

# %% [markdown]
# ## Niblack Thresholding

# %%
binary_method = BinarizationMethod(img_path)
print("Computing features ....")
# binary methods
binary_method.niblack_local(); 
bin_otsu_g = binary_method.binary
plt.imshow(bin_otsu_g, cmap='gray')
# Out:
# Computing features ....

# %% [markdown]
# ## Sauvola Thresholding

# %%
binary_method = BinarizationMethod(img_path)
print("Computing features ....")
# binary methods
binary_method.sauvola_local(); 
bin_otsu_g = binary_method.binary
plt.imshow(bin_otsu_g, cmap='gray')
# Out:
# Computing features ....

# %% [markdown]
# ## Su binarization method

# %%
binary_method = BinarizationMethod(img_path)
print("Computing features ....")
# binary methods
binary_method.su_hybrid(); 
bin_otsu_g = binary_method.binary
plt.imshow(bin_otsu_g, cmap='gray')
# Out:
# Computing features ....

# %% [markdown]
# ## Relative Darkness Index
# This is a for getting feature from text, for example we get 3 types of image, the first highlight the border of the text, the second the background of the document, and the last the text itself.

# %%
binary_method = BinarizationMethod(img_path)
print("Computing features ....")
# binary methods
lower, middle, upper = binary_method.relative_darkness()
plt.imshow(lower, cmap='gray'); plt.show()
plt.imshow(middle, cmap='gray'); plt.show()
plt.imshow(upper, cmap='gray'); plt.show()
# Out:
# Computing features ....

# %% [markdown]
# Doing the arithmetic image operations with image got by relative darkness index I get a clean document image.

# %%
plt.imshow(255-((255-upper)<100), cmap='gray')

# %% [markdown]
# ## Conclusion
# - I decided to use the **Su binarization method**.
# - The result are in the **ourclean_data** folder

# %%
import os
import matplotlib.cm as cm
from imutils import paths

# %%
dataset_path = 'noisy_data'
image_paths = list(paths.list_images(dataset_path))

# %%
for (i, imagePath) in enumerate(image_paths):    
    print(imagePath)    
    binary_method = BinarizationMethod(imagePath)
    binary_method.su_hybrid();     
    plt.imshow(binary_method.binary, cmap='gray')
    plt.show()
    img_name = imagePath.split(os.path.sep)[-1]
    plt.imsave('ourclean_data/'+img_name, binary_method.binary, cmap=cm.gray)
# Out:
# noisy_data/59.png
# noisy_data/152.png
# noisy_data/143.png
# noisy_data/69.png
# noisy_data/192.png
# noisy_data/8.png
# noisy_data/176.png
# noisy_data/215.png
# noisy_data/102.png
# noisy_data/179.png
# noisy_data/74.png
# noisy_data/23.png
# noisy_data/149.png
# noisy_data/45.png
# noisy_data/81.png
# noisy_data/162.png
# noisy_data/171.png
# noisy_data/198.png
# noisy_data/173.png
# noisy_data/194.png
# noisy_data/60.png
# noisy_data/203.png
# noisy_data/128.png
# noisy_data/182.png
# noisy_data/117.png
# noisy_data/188.png
# noisy_data/41.png
# noisy_data/206.png
# noisy_data/125.png
# noisy_data/84.png
# noisy_data/111.png
# noisy_data/116.png
# noisy_data/63.png
# noisy_data/38.png
# noisy_data/27.png
# noisy_data/108.png
# noisy_data/20.png
# noisy_data/11.png
# noisy_data/113.png
# noisy_data/93.png
# noisy_data/53.png
# noisy_data/92.png
# noisy_data/9.png
# noisy_data/159.png
# noisy_data/216.png
# noisy_data/36.png
# noisy_data/48.png
# noisy_data/71.png
# ...
